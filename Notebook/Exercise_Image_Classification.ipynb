# %% [markdown]
# # Exercise 3

# %% [markdown]
# ### Introduction
#
# In the production of electrical drives, a high product quality is needed. As the industry of electric drive production is confronted by trends such as electric mobility and continuing industrial automation, efficient and flexible processes are needed more than ever. With current quality monitoring technology, accurate quality checking is not feasible.
#
# Electrical motors mainly consist of the rotor, the stator and the surrounding housing. The production process can be separated into multiple sub-processes, which can be seen below. The exact sequence of these steps however depends on the motor type. First, the individual components are manufactured and assembled into subassemblies such as the rotor and the stator. Finally, all components (the housing, the stator, the rotor as well as bearings and end shields) are assembled and the motor is checked in an end-of-line (EOL) test.
#
# This final assembly is of great importance, as all parts need to be assembled in the correct way, to ensure smooth operation. Therefore, a quality monitoring system is needed, raising alarm if assembly errors are detected. However, especially in lot-size one production, traditional computer vision systems might reach their limits and cannot be used anymore.
#
# Thus, in this lab we will build a smart quality monitoring system for the electric drives production. An already existing visual sensor captures images of the electric motor after assembly. These images show the part from the top, as well from the side perspective. It is now the target to decide whether the motor is fully assembled, or whether one of multiple defects is present. There is data from three different defects available: *missing cover*, *missing screw* and *not screwed*. Examples of these defects can be seen below. To achieve this, we will investigate two different machine learning models: *Support Vector Machines* (SVM) and *Convolutional Neural Networks* (CNN).
#
# Further background information can be found in this paper: [Mayr et al., Machine Learning in Electric Motor Production - Potentials, Challenges and Exemplary Applications](https://ieeexplore.ieee.org/document/9011861)
#
# ![Introduction](./img/Intro_dataset.png)

# %% [markdown]
# #### Outline
# This lab is structured into two main parts. In the **first part**, a subset of the problem will be analyzed step-by-step. Here, only images from the top view are used and only two of the three defects, the defects *missing cover* and *missing screw* are considered. Your task will be to follow along, fill out missing gaps, and answer problems throughout the notebook.
#
# In the **second part**, you are tasked to expand the quality monitoring system to also detect the defect *not screwed*. Therefore, it might be helpful to also consider images showing the parts in their side perspective. For this part, you are free to choose any of the tools and methods introduced in the first part, and you can expand as you wish!
#
# #### Deliverables
# For completing this exercise successfully, you need to deliver certain results. Throughout the notebook you will find **questions** you need to answer, and coding **tasks** where you need to modify existing code or fill in blanks. Answers to the questions need to be added in the prepared *Your answer here* markdown fields. Coding tasks can be solved by modifying or inserting code in the cells below the task. If needed, you can add extra cells to the notebook, as long as the order of the existing cells remains unchanged. Once you are finished with the lab, you can submit it through the procedure described in the forum. Once the labs are submitted, you will receive feedback regarding the questions. Thus, the **Feedback** boxes need to be left empty
#
# Example:
#
# >**Question:** What do I do if I am stuck solving this lab?
#
# >**Your answer:** <span style="color:green">Have a look at the forum, maybe some of your peers already experienced similiar issues. Otherwise start a new discussion to get help!</span>
#
# >**Feedback:** <span style="color:orange">This is a great approach! Besides asking in the forum I'd also suggest asking your tutor.</span>
#
# #### Ressources
# If you are having issues while completing this lab, feel free to post your questions into the forum. Your peers as well as our teaching advisors will screen the forum regularly and answer open questions. This way, the information is available for fellow students encountering the same issues.

# %%
# Mount your GDrive - Authentication required - Please follow the instructions
from google.colab import drive
from google.colab.patches import cv2_imshow
import sys, os
drive.mount('/content/gdrive')

# Change the current working directory

# Depending on your directory, you may want to adjust this
dir_path = '/content/gdrive/My Drive/ML4Eng_I_Exercise_Image_Classification'
sys.path.append(dir_path)
os.chdir(dir_path)
# Out:
# Mounted at /content/gdrive

# %%
# As in the previous exercises, we'll import commonly used libraries right at the start
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
import tensorflow as tf
# The check.py script contains the quality gates you can use for selftesting throughout the lab
from scripts.check import *

# %% [markdown]
# ## 1 Part one
# To achieve the solution mentioned above, we will execute the following steps in this lab:
#
# 1. First, we will code the necessary functions for loading and preprocessing of the data. We will also set up some methods that help us displaying our progress throughout the exercise
# 2. Second, we will do a short analysis of the existing dataset
# 3. Afterwards, we will start building our first image classification model using SVMs
# 4. Once we are familiar and comfortable with SVMs, we will switch to neural networks and try out CNNs
# 5. Finally, we will introduce data augmentation for improvement of our prediction results.

# %% [markdown]
# ## Section 1.1: Data preprocessing
# The data should be located in the folder called *data* on the same level as this script. Within this folder, two subfolders can be found:
# - The folder **top** contains the top view of each motor
# - The folder **side** contains the side view of each motor
#
# Each motor is uniquely identified by its filename.

# %%
# Loading one image in top view
path = "./data/top/L1_C_3.JPG"
img = cv2.imread(path)
img.shape
# Out:
# (1024, 1024, 3)

# %% [markdown]
# With the snippet above, we are able to load the image from the file into a numpy array, while getting its label from the folder path the image is in.
# To check the type of a python object, you can use the command `type(img)`. It should return *numpy.ndarray*.

# %%
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# Next, we want to plot the image. This can be achieved by executing the following cell.

# %%
plt.title(path.split('/')[-1]) # Set the filename as image title
plt.imshow(img) # Display the image
plt.show()

# %% [markdown]
# By default, open cv assumes the images are encoded in blue, green and red. However, the actual order of the color channels is blue, red and green. Thus, the channels need to be converted using `cv2.COLOR_BGR2RGB`.

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Convert image from bgr to rgb
plt.title(path.split('/')[-1]) # Set the filename as image title
plt.imshow(img) # Display the image
plt.show()

# %% [markdown]
# #### Function for loading multiple images
# Now it's your turn. For the further analysis, we need to load all the available images from the given data folder *folder*. Besides the image, we need to also find the class of the respective image. The information of the class is encoded in the title of each image. You can use the helper function `get_label_from_name(path)` to parse the filename to the class.
#
# >**Task:** Please complete the following function **load_features_labels(folder)**. The function should read the image for a given file, and return two lists:
# >- *features* containing all the images as numpy arrays
# >- *labels* containing the classes of all images

# %%
import glob

def get_label_from_name(path):
    if "_C_" in path:
        return "Complete"
    if "_MC_" in path:
        return "Missing cover"
    if "_MS_" in path:
        return "Missing screw"
    if "_NS_" in path:
        return "Not screwed"
    return "n/a" # TODO: Raise error

def load_features_labels(folder, size = (64,32), flatten = True, color = False, identifiers=['NS', 'MS', 'MC', 'C']):
    features, labels = [], [] # Empty lists for storing the features and labels
    # Iterate over all imagefiles in the given folder
    for file in glob.glob(folder + "/*.JPG"):
        if any(identifier in file for identifier in identifiers):
            #############################
            img = cv2.imread(file)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            features.append(img)
            labels.append(get_label_from_name(file))
            #############################


    return features, labels # Return results

# %% [markdown]
# If everything works as expected, the function should load 117 features and labels. The execution may take a while.

# %%
features, labels = load_features_labels("./data/top")
print("Number of features:", len(features))
print("Number of labels:", len(labels))

# Check data import
quality_gate_111(features, labels)
# Out:
# Number of features: 117
# Number of labels: 117
# 'Quality gate passed :)'

# %% [markdown]
# #### Image preprocessing
# Before analyzing the images using machine learning, they need to be preprocessed. We will do preprocessing regarding three aspects:
# - **Image size**: As the raw images are available in rather high resolution, it might be beneficial to reduce the image resolution. Opencv provides the function `resize()` which works great for that purpose
# - **Image color**: In many use cases, the benefit of considering color information might not outway the increased complexity, thus it might be handy to convert the rgb image to bw. This can easily be done using the `cvtColor` function from opencv.
# - **Image shape**: Only some algorithms are capable of analyzing the 2.5D structure of image data. For the remaining algorithms, which expect the data to be 1D vector, the image data needs to be flattened from 2.5D to 1D. This can be done using the numpy `reshape` functionality.

# %%
def image_preprocessing(img, size = (64,32), flatten = True, color = False):
    img = cv2.resize(img, size)
    if not color:
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    if flatten:
        img = img.reshape(-1)
    return img

# %% [markdown]
# >**Task:** Please update your `load_features_labels(...)` function from above to do image wise data preprocessing using the function `image_preprocessing(...)`. Note that the images shall have the size of 8x8 pixels and be flattened subsequent to the resizing. Therefore be mindfull of argument passing between the two functions!

# %%
def load_features_labels(folder, size = (64,32), flatten = True, color = False, identifiers=['NS', 'MS', 'MC', 'C']):
    features, labels = [], [] # Empty lists for storing the features and labels
    # Iterate over all imagefiles in the given folder
    for file in glob.glob(folder + "/*.JPG"):
        if any(identifier in file for identifier in identifiers):
            #############################
            img = cv2.imread(file)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = image_preprocessing(img, size=size, flatten=flatten, color=color)

            features.append(img)
            labels.append(get_label_from_name(file))
            #############################

    return features, labels # Return results

# %%
################
# Quality gate #
################

features, labels = load_features_labels("./data/top", size=(8, 8), flatten=True, color=False)
quality_gate_112(features, labels)
# Out:
# 'Quality gate passed :)'

# %% [markdown]
# ## Section 1.2: First data analysis
# Before diving into machine learning, we'll have a look at the data. With the snippet below you can visualize a sample of the image data available in this lab. It can be observed that the class *missing cover* is rather distinct to the remaining classes, as the large black plastic cover is missing, exposing the copper wires. The defect *missing screw* is definitely harder to spot as the screws are rather small objects and the color difference between the screw and the empty hole is rather subtle. Finally, the defect *not screwed* can only be seen as some of the screws are not in the shade of the respective hole, thus indicating they are not screwed in all the way.

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(16, 12))
grid = ImageGrid(fig, 111, nrows_ncols=(3, 4), axes_pad=(0.1, 0.3))

features, labels = load_features_labels("./data/top", size=(1024, 1024), flatten=False, color=True)
classes = ['Complete', 'Missing cover', 'Missing screw', 'Not screwed']
for i, ax in enumerate(grid):
    selectedClass = classes[i%4] # Select class
    images = np.array(features)[np.array(labels)==selectedClass] # Preselect images based on class
    image = images[i//4] # Select image
    ax.imshow(image) # Plot image
    ax.set_title(selectedClass) # Assign class as image title
plt.show()

# %% [markdown]
# First, let's investigate the distribution of the available images among the classes.
#
# >**Task:** Please create a plot showing the distribution of the different classes and discuss the distribution in the field below.

# %%
from collections import Counter
print(Counter(labels))
# Out:
# Counter({'Not screwed': 47, 'Missing screw': 42, 'Missing cover': 22, 'Complete': 6})

# %%
#############################

Number = (Counter(labels).values())
Classes = (Counter(labels).keys())
fig = plt.figure()

plt.bar(Classes,Number,color = 'maroon', width = 0.1)
plt.show()
#############################

# %% [markdown]
# >**Question:** Please discuss the class distribution. Which issues and challenges might appear during model training?

# %% [markdown]
# In the bar chart shown we can see the minimum number of complete assemblies are Complete which are 6 and all other have defects. Most number of electric drives are Not screwed. As complete assemblies are very less are model may not be able to be give an accurate answer.

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# ## Section 1.3: Image classification using Support Vector Machines
# In this section, we'll use Support Vector Machines (SVM) to try classifying the image dataset. For SVMs, it is necessary to have the data formatted as 1D vector. Also, as mentioned in the description we are only going to consider the three classes *complete*, *missing cover*, and *missing screws*.

# %%
features, labels = load_features_labels("./data/top", size=(16,16), color=True, flatten=True, identifiers=['MC', 'MS', 'C'])
features = np.asarray(features)
labels = np.asarray(labels)
print("Shape feature vector:", features.shape)
print("Shape label vector:", labels.shape)
# Out:
# Shape feature vector: (70, 768)
# Shape label vector: (70,)

# %% [markdown]
# As we can see, we still load our 117 images, but the pixel values are now simply reshaped to 1D.
# Next, we need to separate our data into training and testing datasets. This can be achieved using the `train_test_split()` function from sklearn. You can find the documentation here: [Link](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
#
# >**Task:** Fill in the following code so that 70% of the data is used for training, and the remaining 30% for testing. Also, the datasets should be stratified by the label vector.

# %%
from sklearn.model_selection import train_test_split
######################################
# Please complete the following line #
######################################

X_train, X_test, y_train, y_test = train_test_split(features,labels,train_size = 0.7, stratify = labels, random_state=42)


################

################

quality_gate_13(X_train, X_test)
# Out:
# 'Quality gate passed :)'

# %%
from sklearn.svm import SVC
from sklearn.utils.class_weight import compute_sample_weight
clf = SVC(kernel="rbf", gamma=0.01, C=0.0003) # Initialize the SVM
clf.fit(X_train, y_train, sample_weight=compute_sample_weight('balanced', y_train)) # Train the SVM
print("Score:", clf.score(X_test, y_test)) # Test the model
# Out:
# Score: 0.6190476190476191

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
cm = confusion_matrix(y_test, clf.predict(X_test))
ax=sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         2
# Missing cover       0.00      0.00      0.00         6
# Missing screw       0.62      1.00      0.76        13
#
#      accuracy                           0.62        21
#     macro avg       0.21      0.33      0.25        21
#  weighted avg       0.38      0.62      0.47        21
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Section 1.4: Image classification with artificial neural networks
#
# In this section, we will train our first artificial neural network (ANN) for image classification.
# First, we will have a look at normal ANNs. These consist of multiple dense layers which can analyze one-dimensional feature vectors. Thus, we need to reshape our 2.5-dimensional image data to 1D using the `flatten` option we integrated into our preprocessing function.
#
# ### a) Image classification using fully connected ANNs
# Again, we need to load the data using the `flatten=True` flag to convert the 2.5D data to 1D.

# %%
features, labels = load_features_labels("./data/top", size=(128,128), color=True, flatten=True, identifiers=['MC', 'MS', 'C'])
features = np.asarray(features)
labels = np.asarray(labels)
print("Shape feature vector:", features.shape)
print("Shape label vector:", labels.shape)
# Out:
# Shape feature vector: (70, 49152)
# Shape label vector: (70,)

# %% [markdown]
# >**Task:** Fill in the following code so that 70% of the data is used for training, and the remaining 30% for testing. Also the datasets should be stratified by the label vector.

# %%
######################################
# Please complete the following line #
######################################
X_train, X_test, y_train, y_test = train_test_split(features,labels,train_size = 0.7, stratify = labels, random_state=42)

# %% [markdown]
# The labels need to be *one hot encoded*. In one hot encoding, categorical values are transformed into a binary representation.
#
# ![OneHotEncoding](./img/OneHotEncoder.png)

# %%
# The sklearn preprocessing library contains a variety of useful data preprocessing tools such as one hot encoding
from sklearn.preprocessing import OneHotEncoder
# Display the first label before encoding
print("Label of first sample before OneHot encoding:", y_train[0])
# Create the encoder object
enc = OneHotEncoder(sparse=False) # Generate Encoder
# With the fit_transform function, the encoder is fitted to the existing labels and transforms the dataset into its binary representation
y_train = enc.fit_transform(y_train.reshape(-1, 1))
# Display the first label after encoding
print("Label of first sample after OneHot encoding:", y_train[0])
# Data preprocessing should always be fitted on the training dataset, but applied to both, the training and the testing dataset. Thus the fit_transform function is only applied to the training dataset, while the the test dataset is transformed using the transform function and the fitted preprocessing module
y_test = enc.transform(y_test.reshape(-1, 1))
# Out:
# Label of first sample before OneHot encoding: Missing cover
# Label of first sample after OneHot encoding: [0. 1. 0.]

# %% [markdown]
# Now, let's define a simple ANN with an input layer, 3 hidden layer and one output layer.
# In this lab we use the **keras** library to model the neural network.
#
# A simple ANN with multiple sequential layers can be created using the `Sequential()` model. Afterwards, various layers can be added to the model through the command `model.add(LAYER)` with *LAYER* defining the layer to be added. In the first layer, the shape of the input needs to be specified using the parameter `input_shape`. This is only necessary in the first, but not in consecutive layers.
#
# Please have a look at the keras documentation regarding the [sequential model](https://keras.io/api/models/sequential/) and the [various layers](https://keras.io/api/layers/). For now, especially the core layers [Dense](https://keras.io/api/layers/core_layers/dense/) and [Activation](https://keras.io/api/layers/core_layers/activation/) are of interest.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Input, Dropout

model = Sequential()
model.add(Dense(32, input_shape = X_train[0].shape))
model.add(Activation("relu"))
model.add(Dense(16))
model.add(Activation("relu"))
model.add(Dense(y_train[0].shape[0]))
model.add(Activation("softmax"))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1572896
#
#  activation (Activation)     (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dense_2 (Dense)             (None, 3)                 51
#
#  activation_2 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 1,573,475
# Trainable params: 1,573,475
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Once the model is created, `model.summary()` displays the architecture of the model. You can see that the created model consists of three *dense* layers, each with an *activation* function. Also, the parameter for each layer are visible. Depending on the selected image size during preprocessing, the input vector might be rather large, thus the high number of parameters in the first dense layer.
#
# Next, the model needs to be compiled using a `loss` function and an `optimizer`. The loss function defines how the loss is computed during model training, while the optimizer defines how the weights need to be adjusted during backpropagation. You can find more information regarding the available losses [here](https://keras.io/api/losses/) and regarding the optimizers [here](https://keras.io/api/optimizers/).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])

# %% [markdown]
# Now, the model can be trained using the datasets defined before.

# %%
model.fit(X_train, y_train, epochs = 20, batch_size = 8, validation_split=0.2, verbose = 1)
# Out:
# Epoch 1/20
# 5/5 [==============================] - 1s 58ms/step - loss: 391.4853 - accuracy: 0.5385 - val_loss: 64.3800 - val_accuracy: 0.4000
# Epoch 2/20
# 5/5 [==============================] - 0s 17ms/step - loss: 207.8239 - accuracy: 0.4872 - val_loss: 53.0921 - val_accuracy: 0.6000
# Epoch 3/20
# 5/5 [==============================] - 0s 17ms/step - loss: 189.9319 - accuracy: 0.3590 - val_loss: 22.0330 - val_accuracy: 0.4000
# Epoch 4/20
# 5/5 [==============================] - 0s 16ms/step - loss: 82.0191 - accuracy: 0.5385 - val_loss: 46.0065 - val_accuracy: 0.3000
# Epoch 5/20
# 5/5 [==============================] - 0s 18ms/step - loss: 35.9589 - accuracy: 0.6154 - val_loss: 98.2396 - val_accuracy: 0.6000
# Epoch 6/20
# 5/5 [==============================] - 0s 16ms/step - loss: 70.5462 - accuracy: 0.6154 - val_loss: 83.2467 - val_accuracy: 0.5000
# Epoch 7/20
# 5/5 [==============================] - 0s 16ms/step - loss: 27.2223 - accuracy: 0.7179 - val_loss: 65.5934 - val_accuracy: 0.5000
# Epoch 8/20
# 5/5 [==============================] - 0s 15ms/step - loss: 3.1498 - accuracy: 0.8718 - val_loss: 35.2215 - val_accuracy: 0.6000
# Epoch 9/20
# 5/5 [==============================] - 0s 16ms/step - loss: 10.4428 - accuracy: 0.7692 - val_loss: 68.8652 - val_accuracy: 0.4000
# Epoch 10/20
# 5/5 [==============================] - 0s 16ms/step - loss: 13.4035 - accuracy: 0.6923 - val_loss: 42.8187 - val_accuracy: 0.6000
# Epoch 11/20
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6331 - accuracy: 0.9487 - val_loss: 46.5561 - val_accuracy: 0.3000
# Epoch 12/20
# 5/5 [==============================] - 0s 17ms/step - loss: 2.4006 - accuracy: 0.8718 - val_loss: 41.5628 - val_accuracy: 0.7000
# Epoch 13/20
# 5/5 [==============================] - 0s 16ms/step - loss: 1.1843 - accuracy: 0.9487 - val_loss: 40.2253 - val_accuracy: 0.6000
# Epoch 14/20
# 5/5 [==============================] - 0s 15ms/step - loss: 9.1699e-09 - accuracy: 1.0000 - val_loss: 42.3805 - val_accuracy: 0.4000
# Epoch 15/20
# 5/5 [==============================] - 0s 15ms/step - loss: 1.3827 - accuracy: 0.9487 - val_loss: 40.0374 - val_accuracy: 0.6000
# Epoch 16/20
# 5/5 [==============================] - 0s 16ms/step - loss: 0.3182 - accuracy: 0.9744 - val_loss: 40.3219 - val_accuracy: 0.6000
# Epoch 17/20
# 5/5 [==============================] - 0s 18ms/step - loss: 0.4668 - accuracy: 0.9487 - val_loss: 41.5751 - val_accuracy: 0.4000
# Epoch 18/20
# 5/5 [==============================] - 0s 20ms/step - loss: 7.0303e-08 - accuracy: 1.0000 - val_loss: 41.8441 - val_accuracy: 0.5000
# Epoch 19/20
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2856 - accuracy: 0.9744 - val_loss: 41.9146 - val_accuracy: 0.5000
# Epoch 20/20
# 5/5 [==============================] - 0s 15ms/step - loss: 4.3403e-06 - accuracy: 1.0000 - val_loss: 40.8490 - val_accuracy: 0.5000

# %% [markdown]
# You can use the following function to evaluate your model.

# %%
def evaluate_model(X_test, y_test, model):
    import seaborn as sns
    from sklearn.metrics import confusion_matrix, classification_report

    y_pred = model.predict(X_test)
    res = np.zeros_like(y_pred)
    for i in range(len(np.argmax(y_pred, axis=1))):
        res[i, np.argmax(y_pred,axis=1)[i]]=1
    y_pred = res
    cm = confusion_matrix(enc.inverse_transform(y_test), enc.inverse_transform(y_pred))
    ax=sns.heatmap(cm, annot=True)
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    print(classification_report(enc.inverse_transform(y_test), enc.inverse_transform(y_pred), zero_division=0))

# %%
evaluate_model(X_test, y_test, model)
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         2
# Missing cover       0.00      0.00      0.00         6
# Missing screw       0.56      0.69      0.62        13
#
#      accuracy                           0.43        21
#     macro avg       0.19      0.23      0.21        21
#  weighted avg       0.35      0.43      0.38        21

# %% [markdown]
# >**Question:** What behavior did you observe while training the model? How can the results be explained?

# %% [markdown]
# >The model didnot train well because only one class missing screw predicted that too with a precision of 0.56. Very large number of parameters and low number of images

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# ### b) Image classification using CNNs
#
# In this section, we are going to explore the usage of CNNs for the given task.
#
# ![Architecture CNN](./img/cnn_structure.png)
#
# First, the data is loaded from file. As CNNs are capable and even excel on analyzing the multiple dimensional aspects of images, the images do not need to be reshaped in a one-dimensional vector. Thus, we have to set the flag `flatten` to `False`. You can see, that the shape of the loaded images is now a four-dimensional array with `(number of samples, width image, height image, color channels image)`.

# %%
features, labels = load_features_labels("./data/top", size=(512,512), color=True, flatten=False, identifiers=['MC', 'MS', 'C'])
features = np.array(features) # Datatype conversion of feature vector from list to array
labels = np.array(labels) # Datatype conversion of label vector from list to array
print("Shape feature vector:", features.shape)
print("Shape label vector:", labels.shape)
# Out:
# Shape feature vector: (70, 512, 512, 3)
# Shape label vector: (70,)

# %% [markdown]
# >**Task:** Fill in the following code so that 70% of the data is used for training, and the remaining 30% for testing. Also, the datasets should be stratified by the label vector. Furthermore, add OneHot Encoding for the labels as seen before.

# %%
#######################################
# Please complete the following lines #
#######################################

def split_data(features, labels):
    return train_test_split(features, labels, train_size=0.7, stratify=labels, random_state=42)

def encode_data(y_train, y_test):
    enc = OneHotEncoder(sparse=False)
    y_train = enc.fit_transform(y_train.reshape(-1, 1))
    y_test = enc.transform(y_test.reshape(-1, 1))
    return y_train, y_test


################
 #Quality gate#
################

X_train, X_test, y_train, y_test = split_data(features, labels)
y_train, y_test = encode_data(y_train, y_test)
print("Label of first sample after OneHot encoding:", y_train[0])
quality_gate_141(y_train, y_test)
# Out:
# Label of first sample after OneHot encoding: [0. 1. 0.]
# 'Quality gate passed :)'

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPooling2D, GlobalMaxPooling2D

model = Sequential()
model.add(Conv2D(8, 5,  input_shape = X_train[0].shape, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(16, 3, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(32, 3, activation = 'relu', padding="same"))
model.add(GlobalMaxPooling2D())
model.add(Dense(32, activation = 'relu'))
model.add(Dense(y_train[0].shape[0], activation = 'softmax'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 512, 512, 8)       608
#
#  max_pooling2d (MaxPooling2D  (None, 256, 256, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)      1168
#
#  max_pooling2d_1 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)      4640
#
#  global_max_pooling2d (Globa  (None, 32)               0
#  lMaxPooling2D)
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dense_4 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 7,571
# Trainable params: 7,571
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import Adam
optimizer=Adam(learning_rate=0.001)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# %%
model.fit(np.array(X_train), np.array(y_train), epochs = 75, batch_size = 32, validation_split=0.1,
          verbose = 1, sample_weight=compute_sample_weight('balanced', y_train))
# Out:
# Epoch 1/75
# 2/2 [==============================] - 10s 3s/step - loss: 31.4131 - accuracy: 0.2273 - val_loss: 23.2806 - val_accuracy: 0.6000
# Epoch 2/75
# 2/2 [==============================] - 9s 3s/step - loss: 23.4346 - accuracy: 0.5455 - val_loss: 12.5653 - val_accuracy: 0.2000
# Epoch 3/75
# 2/2 [==============================] - 9s 3s/step - loss: 9.4418 - accuracy: 0.2500 - val_loss: 7.7293 - val_accuracy: 0.0000e+00
# Epoch 4/75
# 2/2 [==============================] - 9s 3s/step - loss: 5.1864 - accuracy: 0.0909 - val_loss: 2.8035 - val_accuracy: 0.4000
# Epoch 5/75
# 2/2 [==============================] - 9s 3s/step - loss: 3.7793 - accuracy: 0.3182 - val_loss: 2.3609 - val_accuracy: 0.4000
# Epoch 6/75
# 2/2 [==============================] - 8s 3s/step - loss: 2.8121 - accuracy: 0.3636 - val_loss: 1.0779 - val_accuracy: 0.4000
# Epoch 7/75
# 2/2 [==============================] - 9s 3s/step - loss: 1.2202 - accuracy: 0.4545 - val_loss: 0.6636 - val_accuracy: 0.2000
# Epoch 8/75
# 2/2 [==============================] - 9s 3s/step - loss: 1.1799 - accuracy: 0.5227 - val_loss: 0.8466 - val_accuracy: 0.0000e+00
# Epoch 9/75
# 2/2 [==============================] - 9s 3s/step - loss: 1.3121 - accuracy: 0.4773 - val_loss: 0.9627 - val_accuracy: 0.0000e+00
# Epoch 10/75
# 2/2 [==============================] - 9s 3s/step - loss: 1.1737 - accuracy: 0.4091 - val_loss: 1.0779 - val_accuracy: 0.0000e+00
# Epoch 11/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.9750 - accuracy: 0.3864 - val_loss: 0.8577 - val_accuracy: 0.2000
# Epoch 12/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.7347 - accuracy: 0.4091 - val_loss: 0.6254 - val_accuracy: 0.4000
# Epoch 13/75
# 2/2 [==============================] - 8s 3s/step - loss: 0.6366 - accuracy: 0.5455 - val_loss: 0.5360 - val_accuracy: 0.6000
# Epoch 14/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.7787 - accuracy: 0.5455 - val_loss: 0.4730 - val_accuracy: 0.6000
# Epoch 15/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.7529 - accuracy: 0.5909 - val_loss: 0.4032 - val_accuracy: 0.6000
# Epoch 16/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.5488 - accuracy: 0.7273 - val_loss: 0.4037 - val_accuracy: 0.6000
# Epoch 17/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.4131 - accuracy: 0.7273 - val_loss: 0.4607 - val_accuracy: 0.4000
# Epoch 18/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.4044 - accuracy: 0.7045 - val_loss: 0.4690 - val_accuracy: 0.4000
# Epoch 19/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.3838 - accuracy: 0.7500 - val_loss: 0.3998 - val_accuracy: 0.6000
# Epoch 20/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.3149 - accuracy: 0.7955 - val_loss: 0.2929 - val_accuracy: 1.0000
# Epoch 21/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.2558 - accuracy: 0.8409 - val_loss: 0.2314 - val_accuracy: 0.8000
# Epoch 22/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.2166 - accuracy: 0.8636 - val_loss: 0.2319 - val_accuracy: 0.8000
# Epoch 23/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1984 - accuracy: 0.8864 - val_loss: 0.2456 - val_accuracy: 0.8000
# Epoch 24/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1914 - accuracy: 0.8864 - val_loss: 0.2528 - val_accuracy: 0.8000
# Epoch 25/75
# 2/2 [==============================] - 8s 3s/step - loss: 0.1735 - accuracy: 0.9318 - val_loss: 0.2661 - val_accuracy: 0.8000
# Epoch 26/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1544 - accuracy: 0.9545 - val_loss: 0.2765 - val_accuracy: 0.8000
# Epoch 27/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1314 - accuracy: 0.9545 - val_loss: 0.2861 - val_accuracy: 0.8000
# Epoch 28/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1173 - accuracy: 0.9545 - val_loss: 0.2961 - val_accuracy: 0.8000
# Epoch 29/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1048 - accuracy: 0.9773 - val_loss: 0.3018 - val_accuracy: 0.8000
# Epoch 30/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0969 - accuracy: 0.9773 - val_loss: 0.3010 - val_accuracy: 0.8000
# Epoch 31/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0891 - accuracy: 1.0000 - val_loss: 0.2973 - val_accuracy: 0.8000
# Epoch 32/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0805 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.8000
# Epoch 33/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0761 - accuracy: 1.0000 - val_loss: 0.2862 - val_accuracy: 0.8000
# Epoch 34/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0705 - accuracy: 1.0000 - val_loss: 0.2845 - val_accuracy: 1.0000
# Epoch 35/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0653 - accuracy: 1.0000 - val_loss: 0.2740 - val_accuracy: 1.0000
# Epoch 36/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0600 - accuracy: 1.0000 - val_loss: 0.2695 - val_accuracy: 1.0000
# Epoch 37/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 0.2719 - val_accuracy: 1.0000
# Epoch 38/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.2793 - val_accuracy: 1.0000
# Epoch 39/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.8000
# Epoch 40/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.2933 - val_accuracy: 0.8000
# Epoch 41/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0455 - accuracy: 1.0000 - val_loss: 0.2964 - val_accuracy: 0.8000
# Epoch 42/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0436 - accuracy: 1.0000 - val_loss: 0.2978 - val_accuracy: 0.8000
# Epoch 43/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0418 - accuracy: 1.0000 - val_loss: 0.3008 - val_accuracy: 0.8000
# Epoch 44/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.3024 - val_accuracy: 0.8000
# Epoch 45/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.3080 - val_accuracy: 0.8000
# Epoch 46/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.3156 - val_accuracy: 0.8000
# Epoch 47/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.3239 - val_accuracy: 0.8000
# Epoch 48/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.3222 - val_accuracy: 0.8000
# Epoch 49/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.3215 - val_accuracy: 0.8000
# Epoch 50/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.3185 - val_accuracy: 0.8000
# Epoch 51/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.3160 - val_accuracy: 0.8000
# Epoch 52/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.3097 - val_accuracy: 0.8000
# Epoch 53/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.3067 - val_accuracy: 0.8000
# Epoch 54/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.8000
# Epoch 55/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.3076 - val_accuracy: 0.8000
# Epoch 56/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.3121 - val_accuracy: 0.8000
# Epoch 57/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.3182 - val_accuracy: 0.8000
# Epoch 58/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.3236 - val_accuracy: 0.8000
# Epoch 59/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.3272 - val_accuracy: 0.8000
# Epoch 60/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.3300 - val_accuracy: 0.8000
# Epoch 61/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.3255 - val_accuracy: 0.8000
# Epoch 62/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.3204 - val_accuracy: 0.8000
# Epoch 63/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.3184 - val_accuracy: 0.8000
# Epoch 64/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.3180 - val_accuracy: 0.8000
# Epoch 65/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.3204 - val_accuracy: 0.8000
# Epoch 66/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.3280 - val_accuracy: 0.8000
# Epoch 67/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 0.8000
# Epoch 68/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.3392 - val_accuracy: 0.8000
# Epoch 69/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.3363 - val_accuracy: 0.8000
# Epoch 70/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.3285 - val_accuracy: 0.8000
# Epoch 71/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.3246 - val_accuracy: 0.8000
# Epoch 72/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.3229 - val_accuracy: 0.8000
# Epoch 73/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.3245 - val_accuracy: 0.8000
# Epoch 74/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.3286 - val_accuracy: 0.8000
# Epoch 75/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.3336 - val_accuracy: 0.8000

# %% [markdown]
# Evaluate the trained CNN

# %%
evaluate_model(X_test, y_test, model)
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         2
# Missing cover       0.33      0.33      0.33         6
# Missing screw       0.57      0.62      0.59        13
#
#      accuracy                           0.48        21
#     macro avg       0.30      0.32      0.31        21
#  weighted avg       0.45      0.48      0.46        21

# %% [markdown]
# >**Question:**
# >- How does the CNN perform compared to the ANN?
# >- What could be reasons for the different performances?

# %% [markdown]
# Improved performance from ANN but more required. I think less number of parameters and due to many layers and more epochs

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# >**Task:**
# >With the above starter code, a first improvement in accuracy compared to the SVM and the ANN using only Dense layers should be visible. However, the network could be further improved by adjusting the hyperparameters. Below you can find the full snippet from data preprocessing to model training. Play around with the parameters and see whether you can find a model that shows an even better performance!
# >
# >Some ideas are:
# >- Explore different sized images (smaller/larger)
# >- How do black and white images compare to the rgb ones?
# >- Adapt the architecture of the neural network:
# > - Change the amount of Conv2D layers
# > - Change the number of filters in each layer
# > - Explore other activation functions
# >- Change the learning rate of the optimizer or look at different optimizers all together
# >- Train the model for more epochs
# >
# >**For comparability, please don't change the ratios for train/test and train/validation!**

# %%
np.random.seed(28)

####################################################
# Please modify the following lines                #
# ! Don't change training/test/validation ratios ! #
####################################################

# Data preprocessing
features, labels = load_features_labels("./data/top", size=(512,512), color=True, flatten=False, identifiers=['MC', 'MS', 'C'])
features = np.array(features) # Datatype conversion of feature vector from list to array
labels = np.array(labels) # Datatype conversion of label vector from list to array
X_train, X_test, y_train, y_test = split_data(features, labels) # Split features and labels into training and testing datasets
y_train, y_test = encode_data(y_train, y_test) # Encode labels

# Model definition
model = Sequential()
model.add(Conv2D(4, 5,  input_shape = X_train[0].shape, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(8, 3, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(8, 3, activation = 'relu', padding="same"))
model.add(GlobalMaxPooling2D())
model.add(Dense(8, activation = 'relu'))
model.add(Dense(y_train[0].shape[0], activation = 'softmax'))

# Model compilation
optimizer=Adam(learning_rate=0.0005)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# Model training
model.fit(np.array(X_train), np.array(y_train), epochs = 50, batch_size = 2, validation_split=0.1,
          verbose = 1, sample_weight=compute_sample_weight('balanced', y_train))

# Model evaluation
evaluate_model(X_test, y_test, model)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 9s 389ms/step - loss: 24.0717 - accuracy: 0.3182 - val_loss: 6.8322 - val_accuracy: 0.4000
# Epoch 2/50
# 22/22 [==============================] - 8s 376ms/step - loss: 10.0625 - accuracy: 0.3182 - val_loss: 3.7454 - val_accuracy: 0.4000
# Epoch 3/50
# 22/22 [==============================] - 8s 376ms/step - loss: 5.8902 - accuracy: 0.3182 - val_loss: 2.4361 - val_accuracy: 0.4000
# Epoch 4/50
# 22/22 [==============================] - 8s 376ms/step - loss: 3.6023 - accuracy: 0.3182 - val_loss: 1.4207 - val_accuracy: 0.4000
# Epoch 5/50
# 22/22 [==============================] - 8s 375ms/step - loss: 2.6087 - accuracy: 0.3636 - val_loss: 1.1288 - val_accuracy: 0.4000
# Epoch 6/50
# 22/22 [==============================] - 8s 373ms/step - loss: 1.9253 - accuracy: 0.3182 - val_loss: 0.6917 - val_accuracy: 0.4000
# Epoch 7/50
# 22/22 [==============================] - 8s 374ms/step - loss: 1.4499 - accuracy: 0.4091 - val_loss: 0.5680 - val_accuracy: 0.2000
# Epoch 8/50
# 22/22 [==============================] - 8s 376ms/step - loss: 1.2761 - accuracy: 0.5227 - val_loss: 0.6294 - val_accuracy: 0.2000
# Epoch 9/50
# 22/22 [==============================] - 8s 376ms/step - loss: 1.1884 - accuracy: 0.4773 - val_loss: 0.6360 - val_accuracy: 0.2000
# Epoch 10/50
# 22/22 [==============================] - 8s 374ms/step - loss: 1.0701 - accuracy: 0.5227 - val_loss: 0.5548 - val_accuracy: 0.2000
# Epoch 11/50
# 22/22 [==============================] - 8s 374ms/step - loss: 1.0562 - accuracy: 0.5455 - val_loss: 0.5300 - val_accuracy: 0.4000
# Epoch 12/50
# 22/22 [==============================] - 8s 375ms/step - loss: 1.0232 - accuracy: 0.5909 - val_loss: 0.5031 - val_accuracy: 0.4000
# Epoch 13/50
# 22/22 [==============================] - 8s 375ms/step - loss: 1.0078 - accuracy: 0.5909 - val_loss: 0.5528 - val_accuracy: 0.4000
# Epoch 14/50
# 22/22 [==============================] - 8s 377ms/step - loss: 0.9741 - accuracy: 0.6591 - val_loss: 0.6467 - val_accuracy: 0.4000
# Epoch 15/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.9890 - accuracy: 0.5682 - val_loss: 0.7304 - val_accuracy: 0.4000
# Epoch 16/50
# 22/22 [==============================] - 8s 376ms/step - loss: 0.9599 - accuracy: 0.6136 - val_loss: 0.6530 - val_accuracy: 0.4000
# Epoch 17/50
# 22/22 [==============================] - 8s 377ms/step - loss: 0.9729 - accuracy: 0.6818 - val_loss: 0.6473 - val_accuracy: 0.4000
# Epoch 18/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.8997 - accuracy: 0.7273 - val_loss: 0.7382 - val_accuracy: 0.2000
# Epoch 19/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.9170 - accuracy: 0.6364 - val_loss: 0.6295 - val_accuracy: 0.4000
# Epoch 20/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.8889 - accuracy: 0.6591 - val_loss: 0.6513 - val_accuracy: 0.4000
# Epoch 21/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.8478 - accuracy: 0.7500 - val_loss: 0.6690 - val_accuracy: 0.2000
# Epoch 22/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.8309 - accuracy: 0.7727 - val_loss: 0.5900 - val_accuracy: 0.6000
# Epoch 23/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.8278 - accuracy: 0.7500 - val_loss: 0.6138 - val_accuracy: 0.2000
# Epoch 24/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.7941 - accuracy: 0.7727 - val_loss: 0.6583 - val_accuracy: 0.2000
# Epoch 25/50
# 22/22 [==============================] - 8s 376ms/step - loss: 0.7732 - accuracy: 0.7727 - val_loss: 0.6407 - val_accuracy: 0.4000
# Epoch 26/50
# 22/22 [==============================] - 8s 376ms/step - loss: 0.7862 - accuracy: 0.7955 - val_loss: 0.7263 - val_accuracy: 0.2000
# Epoch 27/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.7692 - accuracy: 0.7727 - val_loss: 0.7066 - val_accuracy: 0.4000
# Epoch 28/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.7436 - accuracy: 0.8409 - val_loss: 0.6889 - val_accuracy: 0.6000
# Epoch 29/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.7263 - accuracy: 0.8409 - val_loss: 0.6819 - val_accuracy: 0.4000
# Epoch 30/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.7170 - accuracy: 0.8409 - val_loss: 0.6689 - val_accuracy: 0.4000
# Epoch 31/50
# 22/22 [==============================] - 8s 376ms/step - loss: 0.7067 - accuracy: 0.8409 - val_loss: 0.6747 - val_accuracy: 0.4000
# Epoch 32/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.6941 - accuracy: 0.8409 - val_loss: 0.6334 - val_accuracy: 0.6000
# Epoch 33/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.6901 - accuracy: 0.8409 - val_loss: 0.6602 - val_accuracy: 0.6000
# Epoch 34/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.6740 - accuracy: 0.8636 - val_loss: 0.7169 - val_accuracy: 0.6000
# Epoch 35/50
# 22/22 [==============================] - 8s 377ms/step - loss: 0.6517 - accuracy: 0.8636 - val_loss: 0.6638 - val_accuracy: 0.6000
# Epoch 36/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.6451 - accuracy: 0.8636 - val_loss: 0.6311 - val_accuracy: 0.6000
# Epoch 37/50
# 22/22 [==============================] - 8s 372ms/step - loss: 0.6273 - accuracy: 0.8864 - val_loss: 0.7477 - val_accuracy: 0.6000
# Epoch 38/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.6122 - accuracy: 0.8864 - val_loss: 0.7154 - val_accuracy: 0.6000
# Epoch 39/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.6445 - accuracy: 0.9091 - val_loss: 0.6463 - val_accuracy: 0.4000
# Epoch 40/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.6331 - accuracy: 0.8636 - val_loss: 0.6413 - val_accuracy: 0.4000
# Epoch 41/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.5973 - accuracy: 0.9091 - val_loss: 0.6859 - val_accuracy: 0.6000
# Epoch 42/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.5776 - accuracy: 0.9318 - val_loss: 0.6469 - val_accuracy: 0.6000
# Epoch 43/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.5710 - accuracy: 0.9318 - val_loss: 0.7613 - val_accuracy: 0.6000
# Epoch 44/50
# 22/22 [==============================] - 8s 376ms/step - loss: 0.5619 - accuracy: 0.9318 - val_loss: 0.7727 - val_accuracy: 0.6000
# Epoch 45/50
# 22/22 [==============================] - 8s 373ms/step - loss: 0.5546 - accuracy: 0.9318 - val_loss: 0.7611 - val_accuracy: 0.6000
# Epoch 46/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.5536 - accuracy: 0.9773 - val_loss: 0.6868 - val_accuracy: 0.8000
# Epoch 47/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.5512 - accuracy: 0.9318 - val_loss: 0.7782 - val_accuracy: 0.6000
# Epoch 48/50
# 22/22 [==============================] - 8s 375ms/step - loss: 0.5222 - accuracy: 1.0000 - val_loss: 0.9262 - val_accuracy: 0.6000
# Epoch 49/50
# 22/22 [==============================] - 8s 374ms/step - loss: 0.5270 - accuracy: 1.0000 - val_loss: 0.7903 - val_accuracy: 0.6000
# Epoch 50/50
# 22/22 [==============================] - 8s 376ms/step - loss: 0.4960 - accuracy: 1.0000 - val_loss: 0.9165 - val_accuracy: 0.6000
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         2
# Missing cover       0.55      1.00      0.71         6
# Missing screw       0.90      0.69      0.78        13
#
#      accuracy                           0.71        21
#     macro avg       0.48      0.56      0.50        21
#  weighted avg       0.71      0.71      0.69        21

# %% [markdown]
# >**Question:** Describe your approach optimizing the hyperparameters. Which behavior did you observe?

# %% [markdown]
# ## Section 1.5: Data augmentation
#
# Data augmentation is a technique for artificially increasing the dataset without the need for additional data acquisition. The reason for this is, that most machine learning models perform better the higher the available data volume is.
#
# Data augmentation uses the principle of slight modifications to the original data to create new data, while using the labels of the existing image. As those modifications are rather small, the image as a whole is not changed by a lot and the to be identified object, or in our case image class, can still be recognized. However, the training process can be increased significantly. One can think of many variations of these slight modifications of an image. Typical examples include:
# - Random flipping of the image horizontally or vertically
# - Random rotations
# - Random shifts
# - Blurring the image
# - Adding artificially created noise
# - Cropping
# - Changes in contrast
# - Elastic deformations
#
# Below you can see some examples of the different augmentation strategies applied to our dataset
#
# #### Implementation in keras
# **Keras** includes its own procedure for image augmentation using the `ImageDataGenerator` generator. This generator offers a variety of data augmentation strategies, that are directly applied to the raw data during model training. Thus, the augmented data does not need to be stored to the disk.
#
# For this exercise, we are going to use the ImageDataGenerator from keras. Please have a look at the documentation to get familiar: https://keras.io/api/preprocessing/image/#imagedatagenerator-classData augmentation is a technique for artificially increasing the dataset without the need for additional data acquisition. The reason for this is, that most machine learning models perform better the higher the available data volume is.

# %%
# Data preprocessing
features, labels = load_features_labels("./data/top", size=(512,512), color=True, flatten=False, identifiers=['MC', 'MS', 'C'])
features = np.array(features) # Datatype conversion of feature vector from list to array
labels = np.array(labels) # Datatype conversion of label vector from list to array
X_train, X_test, y_train, y_test = split_data(features, labels) # Split features and labels into training and testing datasets
y_train, y_test = encode_data(y_train, y_test) # Encode labels

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
### Create and show data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)

# %%
random_index = random.randint(0, len(features)) # Randomly select one image
datagen.fit(features[[random_index]]) # Fit the image generator with the randomly selected image

# %%
# Display the random augmentations
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(16, 12))
grid = ImageGrid(fig, 111, nrows_ncols=(3, 4), axes_pad=(0.1, 0.3))

grid[0].imshow(features[random_index])
grid[0].set_title("Original")
for i, ax in enumerate(grid[1:]):
    image = datagen.flow(features[[random_index]]).next()[0].astype(int)
    ax.imshow(image) # Plot image
plt.show()

# %%
### Run model training with given data generator
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, train_size=0.9, stratify=y_train, random_state=21)

datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)

datagen.fit(np.array(X_train))

model = Sequential()
model.add(Conv2D(8, 5,  input_shape = X_train[0].shape, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(8, 5, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(16, 5, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(16, 3, activation = 'relu', padding="same"))
model.add(GlobalMaxPooling2D())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(y_train[0].shape[0], activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])

model.fit(datagen.flow(np.array(X_train), np.array(y_train), batch_size=8), validation_data=(X_validation, y_validation),
          steps_per_epoch=len(X_train) / 8, epochs=50)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 14s 2s/step - loss: 9.5927 - accuracy: 0.2273 - val_loss: 1.2129 - val_accuracy: 0.6000
# Epoch 2/50
# 5/5 [==============================] - 13s 3s/step - loss: 1.2328 - accuracy: 0.5682 - val_loss: 1.5286 - val_accuracy: 0.6000
# Epoch 3/50
# 5/5 [==============================] - 13s 2s/step - loss: 1.2278 - accuracy: 0.4545 - val_loss: 0.7114 - val_accuracy: 0.6000
# Epoch 4/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.9561 - accuracy: 0.5682 - val_loss: 0.5167 - val_accuracy: 0.8000
# Epoch 5/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8364 - accuracy: 0.6136 - val_loss: 0.4575 - val_accuracy: 0.8000
# Epoch 6/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8964 - accuracy: 0.6591 - val_loss: 0.4961 - val_accuracy: 0.8000
# Epoch 7/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.9052 - accuracy: 0.6136 - val_loss: 0.4915 - val_accuracy: 0.6000
# Epoch 8/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8530 - accuracy: 0.6136 - val_loss: 0.5731 - val_accuracy: 0.6000
# Epoch 9/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8373 - accuracy: 0.6364 - val_loss: 0.5509 - val_accuracy: 0.6000
# Epoch 10/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8300 - accuracy: 0.6818 - val_loss: 0.5576 - val_accuracy: 0.6000
# Epoch 11/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8690 - accuracy: 0.5909 - val_loss: 0.5712 - val_accuracy: 0.6000
# Epoch 12/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8812 - accuracy: 0.5682 - val_loss: 0.5897 - val_accuracy: 0.6000
# Epoch 13/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7992 - accuracy: 0.6591 - val_loss: 0.5786 - val_accuracy: 0.6000
# Epoch 14/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8328 - accuracy: 0.6136 - val_loss: 0.5493 - val_accuracy: 0.6000
# Epoch 15/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8527 - accuracy: 0.6136 - val_loss: 0.5793 - val_accuracy: 0.6000
# Epoch 16/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8747 - accuracy: 0.6136 - val_loss: 0.5928 - val_accuracy: 0.6000
# Epoch 17/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8213 - accuracy: 0.7045 - val_loss: 0.5893 - val_accuracy: 0.6000
# Epoch 18/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8488 - accuracy: 0.5909 - val_loss: 0.6201 - val_accuracy: 0.8000
# Epoch 19/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8337 - accuracy: 0.6818 - val_loss: 0.4457 - val_accuracy: 0.8000
# Epoch 20/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8162 - accuracy: 0.6818 - val_loss: 0.4182 - val_accuracy: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7950 - accuracy: 0.7045 - val_loss: 0.4511 - val_accuracy: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7981 - accuracy: 0.7273 - val_loss: 0.4365 - val_accuracy: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7570 - accuracy: 0.6818 - val_loss: 0.4017 - val_accuracy: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8345 - accuracy: 0.7273 - val_loss: 0.3538 - val_accuracy: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7357 - accuracy: 0.7500 - val_loss: 0.3430 - val_accuracy: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8010 - accuracy: 0.7273 - val_loss: 0.3054 - val_accuracy: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8244 - accuracy: 0.6818 - val_loss: 0.3000 - val_accuracy: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7261 - accuracy: 0.7727 - val_loss: 0.2568 - val_accuracy: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7018 - accuracy: 0.7045 - val_loss: 0.3132 - val_accuracy: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6791 - accuracy: 0.7045 - val_loss: 0.1844 - val_accuracy: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8793 - accuracy: 0.7727 - val_loss: 0.1536 - val_accuracy: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7761 - accuracy: 0.6591 - val_loss: 0.1565 - val_accuracy: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7081 - accuracy: 0.7273 - val_loss: 0.1153 - val_accuracy: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6564 - accuracy: 0.7045 - val_loss: 0.0470 - val_accuracy: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7348 - accuracy: 0.7955 - val_loss: 0.1361 - val_accuracy: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7150 - accuracy: 0.7500 - val_loss: 0.1067 - val_accuracy: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6639 - accuracy: 0.7500 - val_loss: 0.2305 - val_accuracy: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7100 - accuracy: 0.7045 - val_loss: 0.1165 - val_accuracy: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6006 - accuracy: 0.7727 - val_loss: 0.1245 - val_accuracy: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7365 - accuracy: 0.7273 - val_loss: 0.1834 - val_accuracy: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6592 - accuracy: 0.7500 - val_loss: 0.2100 - val_accuracy: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7431 - accuracy: 0.7727 - val_loss: 0.1268 - val_accuracy: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8365 - accuracy: 0.6818 - val_loss: 0.5901 - val_accuracy: 0.6000
# Epoch 44/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7157 - accuracy: 0.7273 - val_loss: 0.0565 - val_accuracy: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8251 - accuracy: 0.7500 - val_loss: 0.3255 - val_accuracy: 0.8000
# Epoch 46/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6788 - accuracy: 0.7500 - val_loss: 0.2184 - val_accuracy: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7010 - accuracy: 0.7500 - val_loss: 0.3249 - val_accuracy: 0.8000
# Epoch 48/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6759 - accuracy: 0.7727 - val_loss: 0.3822 - val_accuracy: 0.8000
# Epoch 49/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6663 - accuracy: 0.7500 - val_loss: 0.3091 - val_accuracy: 0.8000
# Epoch 50/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6698 - accuracy: 0.7727 - val_loss: 0.6108 - val_accuracy: 0.8000

# %%
evaluate_model(X_test, y_test, model)
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         2
# Missing cover       0.67      1.00      0.80         6
# Missing screw       1.00      0.92      0.96        13
#
#      accuracy                           0.86        21
#     macro avg       0.56      0.64      0.59        21
#  weighted avg       0.81      0.86      0.82        21

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>
